# %%
# !python Path/to/train.py \
--epochs 100 \
--batch_size 8 \
--root "/Path/to/dataset" \
--trained_models "/Path/to/trained_models" \
--bce_weight 0.5 \
--focal_weight 0.5 \
--dice_weight 0.5 \
--lowerbound -100 \
--upperbound 200 \
--learning_rate 1e-4 \
--stage 2
